# %% [markdown]
# <a href="https://colab.research.google.com/github/nikhita2004/Neural_Networks/blob/main/sweken_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from tqdm import tqdm
# !pip install mltu
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, TensorBoard

from mltu.preprocessors import ImageReader
from mltu.transformers import ImageResizer, LabelIndexer, LabelPadding, ImageShowCV2
from mltu.augmentors import RandomBrightness, RandomRotate, RandomErodeDilate, RandomSharpen
from mltu.annotations.images import CVImage

from mltu.tensorflow.dataProvider import DataProvider
from mltu.tensorflow.losses import CTCloss
from mltu.tensorflow.callbacks import Model2onnx, TrainLogger
from mltu.tensorflow.metrics import CERMetric, WERMetric
import tensorflow as tf
# !pip install ipykernel
# Out:
# Requirement already satisfied: mltu in /usr/local/lib/python3.10/dist-packages (1.2.5)
# Requirement already satisfied: PyYAML>=6.0 in /usr/local/lib/python3.10/dist-packages (from mltu) (6.0.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from mltu) (4.66.6)
# Requirement already satisfied: qqdm==0.0.7 in /usr/local/lib/python3.10/dist-packages (from mltu) (0.0.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from mltu) (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mltu) (1.26.4)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from mltu) (4.10.0.84)
# Requirement already satisfied: Pillow>=9.4.0 in /usr/local/lib/python3.10/dist-packages (from mltu) (11.0.0)
# Requirement already satisfied: onnxruntime>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from mltu) (1.20.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mltu) (3.8.0)
# Requirement already satisfied: addict in /usr/local/lib/python3.10/dist-packages (from qqdm==0.0.7->mltu) (2.4.0)
# Requirement already satisfied: jupyter in /usr/local/lib/python3.10/dist-packages (from qqdm==0.0.7->mltu) (1.1.1)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.15.0->mltu) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.15.0->mltu) (24.3.25)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.15.0->mltu) (24.2)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.15.0->mltu) (3.20.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.15.0->mltu) (1.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mltu) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mltu) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mltu) (4.55.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mltu) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mltu) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mltu) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->mltu) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->mltu) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mltu) (1.17.0)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.10/dist-packages (from coloredlogs->onnxruntime>=1.15.0->mltu) (10.0)
# Requirement already satisfied: notebook in /usr/local/lib/python3.10/dist-packages (from jupyter->qqdm==0.0.7->mltu) (6.5.5)
# Requirement already satisfied: jupyter-console in /usr/local/lib/python3.10/dist-packages (from jupyter->qqdm==0.0.7->mltu) (6.1.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.10/dist-packages (from jupyter->qqdm==0.0.7->mltu) (7.16.4)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.10/dist-packages (from jupyter->qqdm==0.0.7->mltu) (6.29.5)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.10/dist-packages (from jupyter->qqdm==0.0.7->mltu) (7.7.1)
# Requirement already satisfied: jupyterlab in /usr/local/lib/python3.10/dist-packages (from jupyter->qqdm==0.0.7->mltu) (4.3.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime>=1.15.0->mltu) (1.3.0)
# Requirement already satisfied: comm>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from ipykernel->jupyter->qqdm==0.0.7->mltu) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /usr/local/lib/python3.10/dist-packages (from ipykernel->jupyter->qqdm==0.0.7->mltu) (1.8.0)
# Requirement already satisfied: ipython>=7.23.1 in /usr/local/lib/python3.10/dist-packages (from ipykernel->jupyter->qqdm==0.0.7->mltu) (7.34.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.10/dist-packages (from ipykernel->jupyter->qqdm==0.0.7->mltu) (7.4.9)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.10/dist-packages (from ipykernel->jupyter->qqdm==0.0.7->mltu) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.10/dist-packages (from ipykernel->jupyter->qqdm==0.0.7->mltu) (0.1.7)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.10/dist-packages (from ipykernel->jupyter->qqdm==0.0.7->mltu) (1.6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ipykernel->jupyter->qqdm==0.0.7->mltu) (5.9.5)
# Requirement already satisfied: pyzmq>=24 in /usr/local/lib/python3.10/dist-packages (from ipykernel->jupyter->qqdm==0.0.7->mltu) (24.0.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.10/dist-packages (from ipykernel->jupyter->qqdm==0.0.7->mltu) (6.3.3)
# Requirement already satisfied: traitlets>=5.4.0 in /usr/local/lib/python3.10/dist-packages (from ipykernel->jupyter->qqdm==0.0.7->mltu) (5.7.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->jupyter->qqdm==0.0.7->mltu) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->jupyter->qqdm==0.0.7->mltu) (3.6.10)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->jupyter->qqdm==0.0.7->mltu) (3.0.13)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-console->jupyter->qqdm==0.0.7->mltu) (3.0.48)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from jupyter-console->jupyter->qqdm==0.0.7->mltu) (2.18.0)
# Requirement already satisfied: async-lru>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from jupyterlab->jupyter->qqdm==0.0.7->mltu) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in /usr/local/lib/python3.10/dist-packages (from jupyterlab->jupyter->qqdm==0.0.7->mltu) (0.28.1)
# Requirement already satisfied: jinja2>=3.0.3 in /usr/local/lib/python3.10/dist-packages (from jupyterlab->jupyter->qqdm==0.0.7->mltu) (3.1.4)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from jupyterlab->jupyter->qqdm==0.0.7->mltu) (2.2.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from jupyterlab->jupyter->qqdm==0.0.7->mltu) (2.14.2)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /usr/local/lib/python3.10/dist-packages (from jupyterlab->jupyter->qqdm==0.0.7->mltu) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in /usr/local/lib/python3.10/dist-packages (from jupyterlab->jupyter->qqdm==0.0.7->mltu) (0.2.4)
# Requirement already satisfied: setuptools>=40.8.0 in /usr/local/lib/python3.10/dist-packages (from jupyterlab->jupyter->qqdm==0.0.7->mltu) (75.1.0)
# Requirement already satisfied: tomli>=1.2.2 in /usr/local/lib/python3.10/dist-packages (from jupyterlab->jupyter->qqdm==0.0.7->mltu) (2.2.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->qqdm==0.0.7->mltu) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->qqdm==0.0.7->mltu) (6.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->qqdm==0.0.7->mltu) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->qqdm==0.0.7->mltu) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->qqdm==0.0.7->mltu) (3.0.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->qqdm==0.0.7->mltu) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->qqdm==0.0.7->mltu) (0.10.1)
# Requirement already satisfied: nbformat>=5.7 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->qqdm==0.0.7->mltu) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->qqdm==0.0.7->mltu) (1.5.1)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->qqdm==0.0.7->mltu) (1.4.0)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter->qqdm==0.0.7->mltu) (23.1.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter->qqdm==0.0.7->mltu) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter->qqdm==0.0.7->mltu) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter->qqdm==0.0.7->mltu) (0.21.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter->qqdm==0.0.7->mltu) (1.1.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from async-lru>=1.0.0->jupyterlab->jupyter->qqdm==0.0.7->mltu) (4.12.2)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach!=5.0.0->nbconvert->jupyter->qqdm==0.0.7->mltu) (0.5.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.25.0->jupyterlab->jupyter->qqdm==0.0.7->mltu) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx>=0.25.0->jupyterlab->jupyter->qqdm==0.0.7->mltu) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx>=0.25.0->jupyterlab->jupyter->qqdm==0.0.7->mltu) (1.0.7)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx>=0.25.0->jupyterlab->jupyter->qqdm==0.0.7->mltu) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab->jupyter->qqdm==0.0.7->mltu) (0.14.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython>=7.23.1->ipykernel->jupyter->qqdm==0.0.7->mltu) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=7.23.1->ipykernel->jupyter->qqdm==0.0.7->mltu) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=7.23.1->ipykernel->jupyter->qqdm==0.0.7->mltu) (0.7.5)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=7.23.1->ipykernel->jupyter->qqdm==0.0.7->mltu) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=7.23.1->ipykernel->jupyter->qqdm==0.0.7->mltu) (4.9.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from jupyter-client>=6.1.12->ipykernel->jupyter->qqdm==0.0.7->mltu) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter->qqdm==0.0.7->mltu) (4.3.6)
# Requirement already satisfied: jupyter-events>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->qqdm==0.0.7->mltu) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->qqdm==0.0.7->mltu) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->qqdm==0.0.7->mltu) (7.7.0)
# Requirement already satisfied: websocket-client>=1.7 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->qqdm==0.0.7->mltu) (1.8.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook->jupyter->qqdm==0.0.7->mltu) (21.2.0)
# Requirement already satisfied: babel>=2.10 in /usr/local/lib/python3.10/dist-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->qqdm==0.0.7->mltu) (2.16.0)
# Requirement already satisfied: json5>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->qqdm==0.0.7->mltu) (0.10.0)
# Requirement already satisfied: jsonschema>=4.18.0 in /usr/local/lib/python3.10/dist-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->qqdm==0.0.7->mltu) (4.23.0)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.10/dist-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->qqdm==0.0.7->mltu) (2.32.3)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.10/dist-packages (from nbformat>=5.7->nbconvert->jupyter->qqdm==0.0.7->mltu) (2.21.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->jupyter-console->jupyter->qqdm==0.0.7->mltu) (0.2.13)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.10/dist-packages (from terminado>=0.8.3->notebook->jupyter->qqdm==0.0.7->mltu) (0.7.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert->jupyter->qqdm==0.0.7->mltu) (2.6)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio->httpx>=0.25.0->jupyterlab->jupyter->qqdm==0.0.7->mltu) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx>=0.25.0->jupyterlab->jupyter->qqdm==0.0.7->mltu) (1.2.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter->qqdm==0.0.7->mltu) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->qqdm==0.0.7->mltu) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->qqdm==0.0.7->mltu) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->qqdm==0.0.7->mltu) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->qqdm==0.0.7->mltu) (0.22.3)
# Requirement already satisfied: python-json-logger>=2.0.4 in /usr/local/lib/python3.10/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->qqdm==0.0.7->mltu) (3.2.0)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.10/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->qqdm==0.0.7->mltu) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->qqdm==0.0.7->mltu) (0.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->qqdm==0.0.7->mltu) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->qqdm==0.0.7->mltu) (2.2.3)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter->qqdm==0.0.7->mltu) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter->qqdm==0.0.7->mltu) (2.22)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.10/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->qqdm==0.0.7->mltu) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.10/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->qqdm==0.0.7->mltu) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.10/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->qqdm==0.0.7->mltu) (3.0.0)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.10/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->qqdm==0.0.7->mltu) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->qqdm==0.0.7->mltu) (24.11.1)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.10/dist-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->qqdm==0.0.7->mltu) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /usr/local/lib/python3.10/dist-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->qqdm==0.0.7->mltu) (2.9.0.20241206)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.10/dist-packages (6.29.5)
# Requirement already satisfied: comm>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from ipykernel) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /usr/local/lib/python3.10/dist-packages (from ipykernel) (1.8.0)
# Requirement already satisfied: ipython>=7.23.1 in /usr/local/lib/python3.10/dist-packages (from ipykernel) (7.34.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.10/dist-packages (from ipykernel) (7.4.9)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.10/dist-packages (from ipykernel) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.10/dist-packages (from ipykernel) (0.1.7)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.10/dist-packages (from ipykernel) (1.6.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from ipykernel) (24.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ipykernel) (5.9.5)
# Requirement already satisfied: pyzmq>=24 in /usr/local/lib/python3.10/dist-packages (from ipykernel) (24.0.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.10/dist-packages (from ipykernel) (6.3.3)
# Requirement already satisfied: traitlets>=5.4.0 in /usr/local/lib/python3.10/dist-packages (from ipykernel) (5.7.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=7.23.1->ipykernel) (75.1.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython>=7.23.1->ipykernel) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=7.23.1->ipykernel) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=7.23.1->ipykernel) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=7.23.1->ipykernel) (3.0.48)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=7.23.1->ipykernel) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=7.23.1->ipykernel) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=7.23.1->ipykernel) (4.9.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from jupyter-client>=6.1.12->ipykernel) (0.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from jupyter-client>=6.1.12->ipykernel) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (4.3.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel) (0.2.13)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel) (1.17.0)

# %%
base_path="/content/drive/MyDrive/Datasets/IAM_Sentences"
sentences_txt_path = os.path.join(base_path, 'ascii', 'sentences.txt')
sentences_folder_path = os.path.join(base_path, 'sentences')

# %%
dataset, vocab, max_len = [], set(), 0
words = open(sentences_txt_path, "r").readlines()
for line in tqdm(words):
    if line.startswith("#"):
        continue
    line_split = line.split(" ")
    if line_split[2] == "err":
        continue

    folder1 = line_split[0][:3]
    folder2 = line_split[0][:8]
    file_name = line_split[0] + ".png"
    label = line_split[-1].rstrip('\n')

    label = label.replace('|', ' ')

    rel_path = os.path.join(sentences_folder_path, folder1, folder2, file_name)
    if not os.path.exists(rel_path):
        continue

    dataset.append([rel_path, label])
    vocab.update(list(label))
    max_len = max(max_len, len(label))
# Out:
# 100%|██████████| 16777/16777 [00:02<00:00, 7426.49it/s]

# %%
import os
from datetime import datetime

from mltu.configs import BaseModelConfigs

class ModelConfigs(BaseModelConfigs):
    def __init__(self):
        super().__init__()
        self.model_path = os.path.join("Models/04_sentence_recognition", datetime.strftime(datetime.now(), "%Y%m%d%H%M"))
        self.vocab = ""
        self.height = 96
        self.width = 1408
        self.max_text_length = 0
        self.batch_size = 32
        self.learning_rate = 0.0005
        self.train_epochs = 50
        self.train_workers = 20

# %%
from keras import layers
from keras.models import Model
import tensorflow as tf
import mltu
from mltu.tensorflow.model_utils import residual_block


def train_model(input_dim, output_dim, activation="leaky_relu", dropout=0.2):

    inputs = layers.Input(shape=input_dim, name="input")

    # normalize images here instead in preprocessing step
    input = layers.Lambda(lambda x: x / 255)(inputs)

    x1 = residual_block(input, 32, activation=activation, skip_conv=True, strides=1, dropout=dropout)

    x2 = residual_block(x1, 32, activation=activation, skip_conv=True, strides=2, dropout=dropout)
    x3 = residual_block(x2, 32, activation=activation, skip_conv=False, strides=1, dropout=dropout)

    x4 = residual_block(x3, 64, activation=activation, skip_conv=True, strides=2, dropout=dropout)
    x5 = residual_block(x4, 64, activation=activation, skip_conv=False, strides=1, dropout=dropout)

    x6 = residual_block(x5, 128, activation=activation, skip_conv=True, strides=2, dropout=dropout)
    x7 = residual_block(x6, 128, activation=activation, skip_conv=True, strides=1, dropout=dropout)

    x8 = residual_block(x7, 128, activation=activation, skip_conv=True, strides=2, dropout=dropout)
    x9 = residual_block(x8, 128, activation=activation, skip_conv=False, strides=1, dropout=dropout)

    squeezed = layers.Reshape((x9.shape[-3] * x9.shape[-2], x9.shape[-1]))(x9)

    blstm = layers.Bidirectional(layers.LSTM(256, return_sequences=True))(squeezed)
    blstm = layers.Dropout(dropout)(blstm)

    blstm = layers.Bidirectional(layers.LSTM(64, return_sequences=True))(blstm)
    blstm = layers.Dropout(dropout)(blstm)

    output = layers.Dense(output_dim + 1, activation="softmax", name="output")(blstm)

    model = Model(inputs=inputs, outputs=output)
    return model

# %%
configs = ModelConfigs()

configs.vocab = "".join(vocab)
configs.max_text_length = max_len
configs.save()
input_dim = (configs.height, configs.width, 3)
output_dim = len(configs.vocab)
model = train_model(input_dim=input_dim, output_dim=output_dim)

# %%
data_provider = DataProvider(
    dataset=dataset,
    skip_validation=True,
    batch_size=configs.batch_size,
    data_preprocessors=[ImageReader(CVImage)],
    transformers=[
        ImageResizer(configs.width, configs.height, keep_aspect_ratio=True),
        LabelIndexer(configs.vocab),
        LabelPadding(max_word_length=configs.max_text_length, padding_value=len(configs.vocab)),
        ],
)

# Split the dataset into training and validation sets
train_data_provider, val_data_provider = data_provider.split(split = 0.9)

# %%
train_data_provider.augmentors = [
    RandomBrightness(),
    RandomErodeDilate(),
    RandomSharpen(),
    ]

# %%
# !pip install tf2onnx
os.makedirs(configs.model_path, exist_ok=True)

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=configs.learning_rate),
    loss=CTCloss(),
    metrics=[
        CERMetric(vocabulary=configs.vocab),
        WERMetric(vocabulary=configs.vocab)
        ],
    run_eagerly=False
)
model.summary(line_length=110)

# Define callbacks
earlystopper = EarlyStopping(monitor="val_CER", patience=20, verbose=1, mode="min")
checkpoint = ModelCheckpoint(f"{configs.model_path}/model.keras", monitor="val_CER", verbose=1, save_best_only=True, mode="min")
trainLogger = TrainLogger(configs.model_path)
tb_callback = TensorBoard(f"{configs.model_path}/logs", update_freq=1)
reduceLROnPlat = ReduceLROnPlateau(monitor="val_CER", factor=0.9, min_delta=1e-10, patience=5, verbose=1, mode="auto")

# Train the model
model.fit(
    train_data_provider,
    validation_data=val_data_provider,
    epochs=configs.train_epochs,
    callbacks=[earlystopper, checkpoint, trainLogger, reduceLROnPlat, tb_callback],

)

# Save training and validation datasets as csv files
train_data_provider.to_csv(os.path.join(configs.model_path, "train.csv"))
val_data_provider.to_csv(os.path.join(configs.model_path, "val.csv"))
# Out:
# Requirement already satisfied: tf2onnx in /usr/local/lib/python3.10/dist-packages (1.16.1)
# Requirement already satisfied: numpy>=1.14.1 in /usr/local/lib/python3.10/dist-packages (from tf2onnx) (1.26.4)
# Requirement already satisfied: onnx>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from tf2onnx) (1.17.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from tf2onnx) (2.32.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from tf2onnx) (1.17.0)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.10/dist-packages (from tf2onnx) (24.3.25)
# Requirement already satisfied: protobuf~=3.20 in /usr/local/lib/python3.10/dist-packages (from tf2onnx) (3.20.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->tf2onnx) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->tf2onnx) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->tf2onnx) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->tf2onnx) (2024.8.30)
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                   ┃ Output Shape              ┃          Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input (InputLayer)             │ (None, 96, 1408, 3)       │                0 │ -                          │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ lambda_1 (Lambda)              │ (None, 96, 1408, 3)       │                0 │ input[0][0]                │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ conv2d_24 (Conv2D)             │ (None, 96, 1408, 32)      │              896 │ lambda_1[0][0]             │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ batch_normalization_18         │ (None, 96, 1408, 32)      │              128 │ conv2d_24[0][0]            │
# │ (BatchNormalization)           │                           │                  │                            │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ leaky_re_lu_18 (LeakyReLU)     │ (None, 96, 1408, 32)      │                0 │ batch_normalization_18[0]… │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ conv2d_25 (Conv2D)             │ (None, 96, 1408, 32)      │            9,248 │ leaky_re_lu_18[0][0]       │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ batch_normalization_19         │ (None, 96, 1408, 32)      │              128 │ conv2d_25[0][0]            │
# │ (BatchNormalization)           │                           │                  │                            │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ conv2d_26 (Conv2D)             │ (None, 96, 1408, 32)      │              128 │ lambda_1[0][0]             │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ add_9 (Add)                    │ (None, 96, 1408, 32)      │                0 │ batch_normalization_19[0]… │
# │                                │                           │                  │ conv2d_26[0][0]            │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ leaky_re_lu_19 (LeakyReLU)     │ (None, 96, 1408, 32)      │                0 │ add_9[0][0]                │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ dropout_11 (Dropout)           │ (None, 96, 1408, 32)      │                0 │ leaky_re_lu_19[0][0]       │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ conv2d_27 (Conv2D)             │ (None, 48, 704, 32)       │            9,248 │ dropout_11[0][0]           │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ batch_normalization_20         │ (None, 48, 704, 32)       │              128 │ conv2d_27[0][0]            │
# │ (BatchNormalization)           │                           │                  │                            │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ leaky_re_lu_20 (LeakyReLU)     │ (None, 48, 704, 32)       │                0 │ batch_normalization_20[0]… │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ conv2d_28 (Conv2D)             │ (None, 48, 704, 32)       │            9,248 │ leaky_re_lu_20[0][0]       │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ batch_normalization_21         │ (None, 48, 704, 32)       │              128 │ conv2d_28[0][0]            │
# │ (BatchNormalization)           │                           │                  │                            │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ conv2d_29 (Conv2D)             │ (None, 48, 704, 32)       │            1,056 │ dropout_11[0][0]           │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ add_10 (Add)                   │ (None, 48, 704, 32)       │                0 │ batch_normalization_21[0]… │
# │                                │                           │                  │ conv2d_29[0][0]            │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ leaky_re_lu_21 (LeakyReLU)     │ (None, 48, 704, 32)       │                0 │ add_10[0][0]               │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ dropout_12 (Dropout)           │ (None, 48, 704, 32)       │                0 │ leaky_re_lu_21[0][0]       │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ conv2d_30 (Conv2D)             │ (None, 48, 704, 32)       │            9,248 │ dropout_12[0][0]           │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ batch_normalization_22         │ (None, 48, 704, 32)       │              128 │ conv2d_30[0][0]            │
# │ (BatchNormalization)           │                           │                  │                            │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ leaky_re_lu_22 (LeakyReLU)     │ (None, 48, 704, 32)       │                0 │ batch_normalization_22[0]… │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ conv2d_31 (Conv2D)             │ (None, 48, 704, 32)       │            9,248 │ leaky_re_lu_22[0][0]       │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ batch_normalization_23         │ (None, 48, 704, 32)       │              128 │ conv2d_31[0][0]            │
# │ (BatchNormalization)           │                           │                  │                            │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ add_11 (Add)                   │ (None, 48, 704, 32)       │                0 │ batch_normalization_23[0]… │
# │                                │                           │                  │ dropout_12[0][0]           │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ leaky_re_lu_23 (LeakyReLU)     │ (None, 48, 704, 32)       │                0 │ add_11[0][0]               │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ dropout_13 (Dropout)           │ (None, 48, 704, 32)       │                0 │ leaky_re_lu_23[0][0]       │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ conv2d_32 (Conv2D)             │ (None, 24, 352, 64)       │           18,496 │ dropout_13[0][0]           │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ batch_normalization_24         │ (None, 24, 352, 64)       │              256 │ conv2d_32[0][0]            │
# │ (BatchNormalization)           │                           │                  │                            │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ leaky_re_lu_24 (LeakyReLU)     │ (None, 24, 352, 64)       │                0 │ batch_normalization_24[0]… │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ conv2d_33 (Conv2D)             │ (None, 24, 352, 64)       │           36,928 │ leaky_re_lu_24[0][0]       │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ batch_normalization_25         │ (None, 24, 352, 64)       │              256 │ conv2d_33[0][0]            │
# │ (BatchNormalization)           │                           │                  │                            │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ conv2d_34 (Conv2D)             │ (None, 24, 352, 64)       │            2,112 │ dropout_13[0][0]           │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ add_12 (Add)                   │ (None, 24, 352, 64)       │                0 │ batch_normalization_25[0]… │
# │                                │                           │                  │ conv2d_34[0][0]            │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ leaky_re_lu_25 (LeakyReLU)     │ (None, 24, 352, 64)       │                0 │ add_12[0][0]               │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ dropout_14 (Dropout)           │ (None, 24, 352, 64)       │                0 │ leaky_re_lu_25[0][0]       │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ conv2d_35 (Conv2D)             │ (None, 24, 352, 64)       │           36,928 │ dropout_14[0][0]           │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ batch_normalization_26         │ (None, 24, 352, 64)       │              256 │ conv2d_35[0][0]            │
# │ (BatchNormalization)           │                           │                  │                            │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ leaky_re_lu_26 (LeakyReLU)     │ (None, 24, 352, 64)       │                0 │ batch_normalization_26[0]… │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ conv2d_36 (Conv2D)             │ (None, 24, 352, 64)       │           36,928 │ leaky_re_lu_26[0][0]       │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ batch_normalization_27         │ (None, 24, 352, 64)       │              256 │ conv2d_36[0][0]            │
# │ (BatchNormalization)           │                           │                  │                            │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ add_13 (Add)                   │ (None, 24, 352, 64)       │                0 │ batch_normalization_27[0]… │
# │                                │                           │                  │ dropout_14[0][0]           │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ leaky_re_lu_27 (LeakyReLU)     │ (None, 24, 352, 64)       │                0 │ add_13[0][0]               │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ dropout_15 (Dropout)           │ (None, 24, 352, 64)       │                0 │ leaky_re_lu_27[0][0]       │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ conv2d_37 (Conv2D)             │ (None, 12, 176, 128)      │           73,856 │ dropout_15[0][0]           │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ batch_normalization_28         │ (None, 12, 176, 128)      │              512 │ conv2d_37[0][0]            │
# │ (BatchNormalization)           │                           │                  │                            │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ leaky_re_lu_28 (LeakyReLU)     │ (None, 12, 176, 128)      │                0 │ batch_normalization_28[0]… │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ conv2d_38 (Conv2D)             │ (None, 12, 176, 128)      │          147,584 │ leaky_re_lu_28[0][0]       │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ batch_normalization_29         │ (None, 12, 176, 128)      │              512 │ conv2d_38[0][0]            │
# │ (BatchNormalization)           │                           │                  │                            │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ conv2d_39 (Conv2D)             │ (None, 12, 176, 128)      │            8,320 │ dropout_15[0][0]           │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ add_14 (Add)                   │ (None, 12, 176, 128)      │                0 │ batch_normalization_29[0]… │
# │                                │                           │                  │ conv2d_39[0][0]            │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ leaky_re_lu_29 (LeakyReLU)     │ (None, 12, 176, 128)      │                0 │ add_14[0][0]               │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ dropout_16 (Dropout)           │ (None, 12, 176, 128)      │                0 │ leaky_re_lu_29[0][0]       │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ conv2d_40 (Conv2D)             │ (None, 12, 176, 128)      │          147,584 │ dropout_16[0][0]           │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ batch_normalization_30         │ (None, 12, 176, 128)      │              512 │ conv2d_40[0][0]            │
# │ (BatchNormalization)           │                           │                  │                            │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ leaky_re_lu_30 (LeakyReLU)     │ (None, 12, 176, 128)      │                0 │ batch_normalization_30[0]… │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ conv2d_41 (Conv2D)             │ (None, 12, 176, 128)      │          147,584 │ leaky_re_lu_30[0][0]       │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ batch_normalization_31         │ (None, 12, 176, 128)      │              512 │ conv2d_41[0][0]            │
# │ (BatchNormalization)           │                           │                  │                            │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ conv2d_42 (Conv2D)             │ (None, 12, 176, 128)      │           16,512 │ dropout_16[0][0]           │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ add_15 (Add)                   │ (None, 12, 176, 128)      │                0 │ batch_normalization_31[0]… │
# │                                │                           │                  │ conv2d_42[0][0]            │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ leaky_re_lu_31 (LeakyReLU)     │ (None, 12, 176, 128)      │                0 │ add_15[0][0]               │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ dropout_17 (Dropout)           │ (None, 12, 176, 128)      │                0 │ leaky_re_lu_31[0][0]       │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ conv2d_43 (Conv2D)             │ (None, 6, 88, 128)        │          147,584 │ dropout_17[0][0]           │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ batch_normalization_32         │ (None, 6, 88, 128)        │              512 │ conv2d_43[0][0]            │
# │ (BatchNormalization)           │                           │                  │                            │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ leaky_re_lu_32 (LeakyReLU)     │ (None, 6, 88, 128)        │                0 │ batch_normalization_32[0]… │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ conv2d_44 (Conv2D)             │ (None, 6, 88, 128)        │          147,584 │ leaky_re_lu_32[0][0]       │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ batch_normalization_33         │ (None, 6, 88, 128)        │              512 │ conv2d_44[0][0]            │
# │ (BatchNormalization)           │                           │                  │                            │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ conv2d_45 (Conv2D)             │ (None, 6, 88, 128)        │           16,512 │ dropout_17[0][0]           │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ add_16 (Add)                   │ (None, 6, 88, 128)        │                0 │ batch_normalization_33[0]… │
# │                                │                           │                  │ conv2d_45[0][0]            │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ leaky_re_lu_33 (LeakyReLU)     │ (None, 6, 88, 128)        │                0 │ add_16[0][0]               │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ dropout_18 (Dropout)           │ (None, 6, 88, 128)        │                0 │ leaky_re_lu_33[0][0]       │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ conv2d_46 (Conv2D)             │ (None, 6, 88, 128)        │          147,584 │ dropout_18[0][0]           │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ batch_normalization_34         │ (None, 6, 88, 128)        │              512 │ conv2d_46[0][0]            │
# │ (BatchNormalization)           │                           │                  │                            │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ leaky_re_lu_34 (LeakyReLU)     │ (None, 6, 88, 128)        │                0 │ batch_normalization_34[0]… │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ conv2d_47 (Conv2D)             │ (None, 6, 88, 128)        │          147,584 │ leaky_re_lu_34[0][0]       │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ batch_normalization_35         │ (None, 6, 88, 128)        │              512 │ conv2d_47[0][0]            │
# │ (BatchNormalization)           │                           │                  │                            │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ add_17 (Add)                   │ (None, 6, 88, 128)        │                0 │ batch_normalization_35[0]… │
# │                                │                           │                  │ dropout_18[0][0]           │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ leaky_re_lu_35 (LeakyReLU)     │ (None, 6, 88, 128)        │                0 │ add_17[0][0]               │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ dropout_19 (Dropout)           │ (None, 6, 88, 128)        │                0 │ leaky_re_lu_35[0][0]       │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ reshape_1 (Reshape)            │ (None, 528, 128)          │                0 │ dropout_19[0][0]           │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ bidirectional_2                │ (None, 528, 512)          │          788,480 │ reshape_1[0][0]            │
# │ (Bidirectional)                │                           │                  │                            │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ dropout_20 (Dropout)           │ (None, 528, 512)          │                0 │ bidirectional_2[0][0]      │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ bidirectional_3                │ (None, 528, 128)          │          295,424 │ dropout_20[0][0]           │
# │ (Bidirectional)                │                           │                  │                            │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ dropout_21 (Dropout)           │ (None, 528, 128)          │                0 │ bidirectional_3[0][0]      │
# ├────────────────────────────────┼───────────────────────────┼──────────────────┼────────────────────────────┤
# │ output (Dense)                 │ (None, 528, 76)           │            9,804 │ dropout_21[0][0]           │
# └────────────────────────────────┴───────────────────────────┴──────────────────┴────────────────────────────┘
#  Total params: 2,427,596 (9.26 MB)
#  Trainable params: 2,424,652 (9.25 MB)
#  Non-trainable params: 2,944 (11.50 KB)
# Epoch 1/50
# 2024-12-13 14:43:40.017954: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:966] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inStatefulPartitionedCall/functional_1_1/dropout_11_1/stateless_dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - CER: 2.0596 - WER: 1.0019 - loss: 627.8575
# Epoch 1: val_CER improved from inf to 1.28460, saving model to Models/04_sentence_recognition/202412131442/model.keras
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 134s 1s/step - CER: 2.0510 - WER: 1.0018 - loss: 624.2194 - val_CER: 1.2846 - val_WER: 1.0003 - val_loss: 121.7133 - learning_rate: 5.0000e-04
# Epoch 2/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - CER: 1.2025 - WER: 1.0002 - loss: 120.1676
# Epoch 2: val_CER improved from 1.28460 to 1.14230, saving model to Models/04_sentence_recognition/202412131442/model.keras
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 115s 1s/step - CER: 1.2019 - WER: 1.0002 - loss: 120.1538 - val_CER: 1.1423 - val_WER: 1.0002 - val_loss: 123.5216 - learning_rate: 5.0000e-04
# Epoch 3/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - CER: 1.1173 - WER: 1.0001 - loss: 116.1976
# Epoch 3: val_CER improved from 1.14230 to 1.09487, saving model to Models/04_sentence_recognition/202412131442/model.keras
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 117s 1s/step - CER: 1.1170 - WER: 1.0001 - loss: 116.2039 - val_CER: 1.0949 - val_WER: 1.0001 - val_loss: 134.9738 - learning_rate: 5.0000e-04
# Epoch 4/50
# 68/85 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - CER: 1.0849 - WER: 1.0001 - loss: 116.4965

# %%
import os
print(os.getcwd())
configs.save()

# %%
import cv2
import typing
import numpy as np

from mltu.inferenceModel import OnnxInferenceModel
from mltu.utils.text_utils import ctc_decoder, get_cer, get_wer
from mltu.transformers import ImageResizer

class ImageToWordModel(OnnxInferenceModel):
    def __init__(self, char_list: typing.Union[str, list], *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.char_list = char_list

    def predict(self, image: np.ndarray):
        image = ImageResizer.resize_maintaining_aspect_ratio(image, *self.input_shape[:2][::-1])

        image_pred = np.expand_dims(image, axis=0).astype(np.float32)

        preds = self.model.run(None, {self.input_name: image_pred})[0]

        text = ctc_decoder(preds, self.char_list)[0]

        return text

if __name__ == "__main__":
    import pandas as pd
    from tqdm import tqdm
    from mltu.configs import BaseModelConfigs

    configs = BaseModelConfigs.load("Models/04_sentence_recognition/202412131151/configs.yaml")

    model = ImageToWordModel(model_path=configs.model_path, char_list=configs.vocab)

    df = pd.read_csv("Models/04_sentence_recognition/202301131202/val.csv").values.tolist()

    accum_cer, accum_wer = [], []
    for image_path, label in tqdm(df):
        image = cv2.imread(image_path)

        prediction_text = model.predict(image)

        cer = get_cer(prediction_text, label)
        wer = get_wer(prediction_text, label)
        print("Image: ", image_path)
        print("Label:", label)
        print("Prediction: ", prediction_text)
        print(f"CER: {cer}; WER: {wer}")

        accum_cer.append(cer)
        accum_wer.append(wer)

        cv2.imshow(prediction_text, image)
        cv2.waitKey(0)
        cv2.destroyAllWindows()

    print(f"Average CER: {np.average(accum_cer)}, Average WER: {np.average(accum_wer)}")
